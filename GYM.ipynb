# %%
import mysql.connector

mydb=mysql.connector.connect(
    host="localhost",
    user="root",
    passwd="Rohit@123"
)
c=mydb.cursor()
c.execute("create database gym_management")
c.execute("use gym_management")
c.execute("create table `Customer`(""`user_id` int," "`name` varchar(20)," "`age` int," "`phoneNo` bigint(20)," "`emailAddress` varchar(320)," "`R_fees` int"")")
c.execute("create table `Trainer`(""`trainer_id` int," "`name` varchar(20)," "`age` int," "`phoneNo` bigint(20)," "`emailAddress` varchar(320)," "`salary` int"")")
print("Customer table is created.....")
print("Trainer table is created......")

#c.execute("insert into Customer values(1,'rohit',22,634565545,'yadavrohit1510@gmail.com')")
#c.execute("insert into Customer values(2,'rohit1',23,832455,'yadavbharti1510@gmail.com')")
#mydb.commit()
#mydb.close()

# %%
class GYM: 
    def Owner(self):
        print("\n___Welcome OWNER___ \n")

        while (1):

            t=int(input("1.View Customers\n2.View Trainers\n3.Create Account of Trainers\n4.Delete/Update/CheckBlance/checksalary\n5.Exit\nEnter your Choice :"))

            if(t==1):
                print("\n___View Customer Details : ___ \n")
                c.execute("select * from Customer")
                roh=c.fetchall()
                print(roh)
                '''
                for i in roh:
                    print(i)
                '''    
            elif(t==2):
                print("\n__View Trainers Details:__")
                c.execute("select * from Trainer")
                roh1=c.fetchall()
                print(roh1)
                '''
                for i in roh1:
                    print(i)
                '''    
            elif(t==3):
                print("\n__Create Account of Trainer::__\n")
                trainer_id=int(input("Enter ID"))
                name=input("Enter the name")
                age=int(input("Enter the age"))
                phoneNo=int(input("Enter the contact No."))
                emailAddress=input("Enter the email Address")
                salary=int(input("Enter his Salary"))
                c.execute("insert into Trainer values (%d,'%s',%d,%d,'%s',%d)"%(trainer_id,name,age,phoneNo,emailAddress,salary))
                mydb.commit()    

            elif(t==4):
                while (1):
                    e=int(input("1.From Customer table\n2.From Trainer Table\n3.Exit\nEnter your choice"))
                    if(e==1):
                        uid=input("Enter Customer id :")
                        c.execute("select name from Customer where user_id = %s" %(uid,))
                        res1=c.fetchall()
                        print(res1)
                        
                        if(res1):
                            n=res1[0][0]
                            print("\n -- Welcome in",n,"account--\n")
                            while (1):
                                y=int(input("1.Check_Registration_Fees\n2.Delete\n3.Update\n4.Exit\nEnter your choice"))
                                if(y==1):
                                    print("\n -- Displaying_Registration_Fees : -- \n")
                                    c.execute('select R_fees from Customer where user_id=%s'%(uid,))
                                    fees=c.fetchall()
                                    x=int(fees[0][0])
                                    print("Registration fees is :",x)
                                    mydb.commit()
                                elif(y==2):
                                    print("\n--Delete any Customer Information:--\n")
                                    c.execute('delete from Customer where user_id=%s'%(uid,))
                                    print("Information deletion succefull")
                                    mydb.commit()
                                elif(y==3):
                                    print("\n__Update any information\n")
                                    pt=int(input("Enter Phone No."))
                                    c.execute('update Customer set phoneNo=%s where user_id=%s'%(pt,uid,))
                                    print("Update phoneNo.")
                                    mydb.commit()
                                elif(y==4):
                                    break
                        else:
                            print(" Sorry !!! ID not found .. ")

                    elif(e==2):
                        uid=input("Enter Trainer id :")
                        c.execute('select name from Trainer where user_id=%s'%(uid,))
                        res1=c.fetchall()
                        if(res1):
                            n=res1[0][0]
                            print("\n -- Welcome in",n,"account\n")
                            while (1):
                                y=int(input("1.Check_salary\n2.Delete\n3.Update\n4.Exit\nEnter your choice"))
                                if(y==1):
                                    print("\n -- Displaying_Salary : -- \n")
                                    c.execute('select salary from Trainer where user_id=%s'%(uid,))
                                    fees=c.fetchall()
                                    x=int(fees[0][0])
                                    print("Salary of trainer is :",x)
                                    mydb.commit()
                                elif(y==2):
                                    print("\n--Delete any Trainer Information:--\n")
                                    c.execute('delete from Trainer where user_id=%s'%(uid,))
                                    print("Information deletion successfull")
                                    mydb.commit()
                                elif(y==3):
                                    print("\n__Update any information\n")
                                    pt=int(input("Enter Phone No."))
                                    c.execute('update Trainer set phoneNo=%s where user_id=%s'%(pt,uid,))
                                    print("Update phoneNo.")
                                    mydb.commit()
                                elif(y==4):
                                    break
                        else:
                            print(" Sorry !!! ID not found .. ")


                    elif(e==3):
                        break    



            elif(t==5):
                break



    def Customer(self):
        print("\n__Welcome CUSTOMER__\n")

        while (1):
            t1=int(input("1.Create Account\Deposit Registration Fees\n2.View Details\n3.Exit\nEnter your Choice :"))        
            if(t1==1):
                user_id=int(input("Enter ID"))
                name=input("Enter the name")
                age=int(input("Enter the age"))
                phoneNo=int(input("Enter the contact No."))
                emailAddress=input("Enter the email Address")
                R_fees=int(input("Enter the registration fees"))
                c.execute("insert into Customer values (%d,'%s',%d,%d,'%s',%d)"%(user_id,name,age,phoneNo,emailAddress,R_fees))
                mydb.commit()
                
            elif(t1==2):
                uid=int(input("Enter ID"))
                #c.execute("select name from Customer where user_id = %s" %(uid,))
                #res1=c.fetchall()
                #print(res1)
                c.execute('select * from Customer where user_id=%s'%(uid,))
                res2=c.fetchall()
                print(res2)
                
                
                
            elif(t1==3):
                
obj=GYM() 
while 1: 
    p=int(input("1.Owner\n2.Customer\n3.Exit\nEnter choice :")) 
    if(p==1):
        obj.Owner() 
    elif(p==2):
        obj.Customer()
    elif(p==3):
        print("Exiting")
        break
